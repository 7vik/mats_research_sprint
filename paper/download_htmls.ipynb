# %%
! wget https://github.com/jmsdao/mats5/raw/main/figs/mistral-project-onto-direction.html
# ! wget https://raw.githubusercontent.com/7vik/mats_research_sprint/master/wget_plotlies.sh
! bash wget_plotlies.sh
# Out:
# --2024-01-15 05:33:49--  https://github.com/jmsdao/mats5/raw/main/figs/mistral-project-onto-direction.html
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response...
# 302 Found
# Location: https://raw.githubusercontent.com/jmsdao/mats5/main/figs/mistral-project-onto-direction.html [following]
# --2024-01-15 05:33:49--  https://raw.githubusercontent.com/jmsdao/mats5/main/figs/mistral-project-onto-direction.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4202044 (4.0M) [text/plain]
# Saving to: ‘mistral-project-onto-direction.html.2’
#
# mistral-project-ont 100%[===================>]   4.01M  --.-KB/s    in 0.02s
#
# ...
